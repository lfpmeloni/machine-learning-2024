# %%
# Import Required Packages
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler

# Loading and examining the dataset
nations_df = pd.read_csv("nations.csv")

# %%
nations_df.head()
# Out:
#   iso3c      country      region  year  gdp_percap  life_expect  population  \
# 0   AFG  Afghanistan  South Asia  1990         NaN    49.861049  12067570.0
# 1   AFG  Afghanistan  South Asia  1991         NaN    50.640976  12789374.0
# 2   AFG  Afghanistan  South Asia  1992         NaN    51.362927  13745630.0
# 3   AFG  Afghanistan  South Asia  1993         NaN    52.021878  14824371.0
# 4   AFG  Afghanistan  South Asia  1994         NaN    52.614341  15869967.0
#
#    birth_rate  neonat_mortal_rate      income
# 0      49.029                52.8  Low income
# 1      48.896                51.9  Low income
# 2      48.834                50.9  Low income
# 3      48.839                49.9  Low income
# 4      48.898                49.1  Low income

# %%
nations_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4975 entries, 0 to 4974
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   iso3c               4975 non-null   object
#  1   country             4975 non-null   object
#  2   region              4975 non-null   object
#  3   year                4975 non-null   int64
#  4   gdp_percap          4500 non-null   float64
#  5   life_expect         4820 non-null   float64
#  6   population          4969 non-null   float64
#  7   birth_rate          4874 non-null   float64
#  8   neonat_mortal_rate  4675 non-null   float64
#  9   income              4975 non-null   object
# dtypes: float64(5), int64(1), object(4)
# memory usage: 388.8+ KB

# %%
nations_df.describe()
# Out:
#               year     gdp_percap  life_expect    population   birth_rate  \
# count  4975.000000    4500.000000  4820.000000  4.969000e+03  4874.000000
# mean   2002.000000   12790.702785    67.798630  3.127845e+07    24.224782
# std       7.211827   16297.862233     9.898495  1.224760e+08    11.842941
# min    1990.000000     239.739376    27.078902  9.004000e+03     6.900000
# 25%    1996.000000    2264.885916    61.311579  1.193148e+06    13.500000
# 50%    2002.000000    6577.176462    70.441354  5.786794e+06    21.754500
# 75%    2008.000000   17198.183309    75.116262  1.932259e+07    33.910500
# max    2014.000000  141968.100275    83.980488  1.364270e+09    55.122000
#
#        neonat_mortal_rate
# count         4675.000000
# mean            19.392620
# std             14.896943
# min              0.700000
# 25%              7.000000
# 50%             15.100000
# 75%             29.300000
# max             73.100000

# %% [markdown]
# No missing values to handle

# %%
# Pairplot to visualize distributions and relationships
sns.pairplot(nations_df, vars=['gdp_percap', 'life_expect', 'population', 'birth_rate', 'neonat_mortal_rate'], hue='region', palette='viridis')
plt.suptitle("Pairplot of Numerical Features by Region", y=1.02)
plt.show()
